# %%
from dataclasses import  dataclass

from django.core.exceptions import ValidationError
from pydantic.v1.class_validators import Validator


@dataclass(frozen=True)
class Raza:
    x : str

    name = x
    print (f" Welcom to Mr. : {x}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 from dataclasses import  dataclass
#       4 @dataclass(frozen=True)
# ----> 5 class Raza:
#       6     x : str
#       8     name = x
#
# Cell In[2], line 8, in Raza()
#       4 @dataclass(frozen=True)
#       5 class Raza:
#       6     x : str
# ----> 8     name = x
#       9     print (f" Welcom to Mr. : {x}")
#
# NameError: name 'x' is not defined

# %%
from dataclasses import dataclass

@dataclass(frozen=True)
class Raza:
    x: str

    def __post_init__(self):
        print(f"Welcome Mr. {self.x}")

Raza("Raza")
# Out:
# Welcome Mr. Raza
# Raza(x='Raza')

# %%
@dataclass(frozen=False)
class Raza:
    x: int
    y: int
    def sum(self):
        c = self.x + self.y
        return f"Your answer {c}"

# %%
Raza(3,7).sum()
# Out:
# 'Your answer 10'

# %%
s = Raza(4,5)
print(s)
# Out:
# Raza(x=4, y=5)

# %%
@dataclass(frozen=False)
class CreatRMResults:
    rm: RM

    def creat_rm(
            rname: str,
            email: str,
            phone: str,
            team: str
    ):
        name = (rname or "").strip()
        if not name:
            raise ValidationError()
r
# Out:
# 'Your answer 14'

# %%
rm_name = ""

name = (rm_name or "").strip()
if not name:
    raise ValidationError("rm_name is required.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       3 name = (rm_name or "").strip()
#       4 if not name:
# ----> 5     raise ValidationError("rm_name is required.")
#
# NameError: name 'ValidationError' is not defined

# %%
print(("").strip())
